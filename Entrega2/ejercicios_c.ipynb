# %% [markdown]
# <h3 align="center">High Performance Computing</h3>
# <h3 align="center">Computación de Alto Desempeño</h3>
# <h3 align="center">Entrega 2 - Ejercicios prácticos de C</h3>
# <h3 align="center">Marzo - 2025</h3>
# <h3 align="center">Universidad de Medellín </h3>
# <h5 align="center">Paula S. Meneses Gasca </h5>
#
# ***

# %% [markdown]
# # Introducción

# %% [markdown]
# En este trabajo se hará uso de un nuevo lenguaje de programación para implementar estructuras de datos y algoritmos en C.
# C es utilizada en la computación de alto desempeño por el control que tiene sobre la memoria y su cercanía al hardware, lo que permite escribir código optimizado para tareas computacionalmente exigentes.
#
# Los ejercicios se van a implementar de manera secuencial, buscando entender algunas bases para paralelizar en otro momento. Se van a implementar y evaluar aspectos como la eficiencia del código, el manejo de memoria y el tiempo de ejecución en algunos casos.
#
# De cada ejercicio se explicarán los fundamentos teóricos que fueron aplicados, la estructura del código y los resultados obtenidos. Este análisis servirá el inicio para futuras optimizaciones y mejoras en el desempeño del código.
#
# ***

# %% [markdown]
# # Ejercicio 6

# %% [markdown]
# ### Suma de matrices
# **Problema**
#
# Escriba un programa en C que:
#
# 1. Lea desde archivos de datos dos matrices.
# 2. Calcule su suma.
# 3. Muestre la matriz resultante.
#
# **Objetivo**
# - Introducir arreglos bidimensionales.
# - Uso de ciclos anidados.

# %% [markdown]
# Este fue el código que planteé inicialmente, sin embargo al revisarlo me di cuenta que por ejemplo la creación de matrices es la misma para las dos, por lo que decidí cambiarlo y hacerlo con algunas funciones que se llamarían en la principal. El siguiente código fue el planteado en un inicio:

# %%
#include <stdio.h>

// Crear la función principal
int main() {

    // Definir una variable que el usuario ingresa para establecer las dimensiones de las matrices
    int n;

    printf("Ingrese de que tamaño desea la matriz cuadrada: ");
    scanf("%d", &n);

    // Definir las matrices con su tamaño n
    int matriz1[n][n];
    int matriz2[n][n];
    int suma[n][n];
    
    // Pedir al usuario que ingrese los elementos para generar la primera matriz
    printf("Ingrese los elementos de la primera matriz (%d x %d):\n", n, n);
    // Para esto implementamos un ciclo for anidado que recorre la matriz
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            printf("Elemento [%d][%d]: ", i, j);
            scanf("%d", &matriz1[i][j]);
        }
    }
    
    // Pedir al usuario que ingrese los elementos para generar la segunda matriz
    printf("Ingrese los elementos de la segunda matriz (%d x %d):\n", n, n);
   // Para esto implementamos un ciclo for anidado que recorre la matriz
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            printf("Elemento [%d][%d]: ", i, j);
            scanf("%d", &matriz2[i][j]);
        }
    }

    // Calcular la suma de las matrices también con un ciclo for anidado que busca recorrer las matrices y se le asigna a la nueva matriz la suma de las dos matrices
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            suma[i][j] = matriz1[i][j] + matriz2[i][j];
        }
    }

    // Imprimir la matriz resultante en pantalla
    printf("La suma de las matrices es:\n");
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            printf("%d ", suma[i][j]);
        }
        printf("\n");
    }

    return 0; 
}

# %% [markdown]
# #### Explicación detallada del Ejercicio 6 - código 1
#
# Este ejercicio permite que el usuario ingrese dos matrices cuadradas de tamaño n × n y calcula la suma de estas dos.
#
# En este ejercicio:
#
# 1. Se importan las librerias necesarias
#
#     `#include <stdio.h>` - Esta libreria permite manejar la entrada y salida de datos (printf,  scanf).
#
# 2. Se define la función principal donde se va a ejecutar el programa.
#
# 3. Se crean las variables neecesarias, en este caso primero creamos la variable `n`, la cual se le pide al usuario con el `printf`; luego de esto se crean las dos matrices del tamaño n que dió el usuario.
#
# 4. Teniendo n procedemos a pedirle al usuario los datos para cada matriz, estos los recolectamos por medio de un ciclo for en el que recorremos la matriz y le asignamos el número a cada posición. Para esto usamos los índices i y j.
#
# ```c
#     for (int i = 0; i < n; i++) {
#         for (int j = 0; j < n; j++) {
#             printf("Elemento [%d][%d]: ", i, j);
#             scanf("%d", &matriz2[i][j]);
#         }
#     }
# ```
#
# - En este for anidado se recorren las filas con i, mientras i sea menor a el tamaño de la matriz va a realizar el for recorriendo la lista, i se va a incrementar de a 1 para poder iterar.
# - El segundo for se recorren las columnas con j, mientras j sea menor al tamaño de la matriz va a realizar el for recorriendo la lista, al igual que i, j se va a incrementar de a 1 para poder iterar.
# - Con `printf` se le pide al usuario cada número, dentro del ciclo.
# - Con `scanf` se le asigna el valor dado por el usuario a la posición i, j en la que se encuentra.
#
# 5. El ciclo pasado se ejecuta dos veces para capturar las dos matrices.
#
# 6. Para la suma de matrices es necesario implementar un ciclo anidado como el recien explicado, para recorrer las matrices y poder acceder a la misma posición en las dos.
# `suma[i][j] = matriz1[i][j] + matriz2[i][j];`
# Con esta linea , asignamos a la posición i, j de la matriz suma(es el resultado) la suma de los elementos que se encuentran en la misma posición de las deos matrices que se van a sumar.
#
# 7. En el siguiente paso se imprime en pantalla la matriz resultante, para esto debemos recorrer la matriz y mostrar el resultado, además saltamos de linea cada que se recorre una fila para mostrarlo con la estructura de una matriz.
#
# 8. Finalmente retornamos 0 para mostrar el fin exitoso de la función principal.

# %% [markdown]
# Este código se puede organizar de otra manera para que no repita tantas cosas iguales, al crear el nuevo código, donde creo una funcion para capturar n y otra para capturar las matrices, me di cuenta que era necesario realizar un `malloc`, en este punto usé una IA para entender bien el proposito de usarlo y saber en que punto era necesario hacerlo. El código con las nuevas funciones es el siguiente:

# %%
#include <stdio.h>
#include <stdlib.h>

int capturar_tamaño() {
    
    // Definir una variable que el usuario ingresa para establecer las dimensiones de las matrices
    int n;

    printf("Ingrese de que tamaño desea la matriz: ");
    scanf("%d", &n);

    // Validar que el tamaño sea positivo
    if (n <= 0) {
        printf("El tamaño de la matriz debe ser positivo.\n");
        return 1; // Salir con un código de error
    }

    return n; // Retornar el tamaño de la matriz
}

int** capturar_matriz(int n) {

    // Reservar memoria dinámica para la matriz
    int** matriz = (int**)malloc(n * sizeof(int*));
    for (int i = 0; i < n; i++) {
        matriz[i] = (int*)malloc(n * sizeof(int));
    }

    // Pedir al usuario que ingrese los elementos para generar la primera matriz
    printf("Ingrese los elementos de la primera matriz (%d x %d):\n", n, n);
    // Para esto implementamos un ciclo for anidado que recorre la matriz
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            printf("Elemento [%d][%d]: ", i, j);
            scanf("%d", &matriz[i][j]);
        }
    }

    return matriz; 
}

void liberar_matriz(int** matriz, int n) {
    for (int i = 0; i < n; i++) {
        free(matriz[i]);
    }
    free(matriz);
}

int main(int n) {

    // Llamar a la función para capturar el tamaño de la matriz
    n = capturar_tamaño();

    // Definir las matrices con su tamaño n
    int** matriz1 = capturar_matriz(n);
    int** matriz2 = capturar_matriz(n);

    // Asignar memoria dinamica para la matriz suma
    int** suma = (int**)malloc(n * sizeof(int*));
    for (int i = 0; i < n; i++) {
        suma[i] = (int*)malloc(n * sizeof(int));
    }

    // Calcular la suma de las matrices también con un ciclo for anidado que busca recorrer las matrices y se le asigna a la nueva matriz la suma de las dos matrices
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            suma[i][j] = matriz1[i][j] + matriz2[i][j];
        }
    }

    // Imprimir la matriz resultante en pantalla
    printf("La suma de las matrices es:\n");
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            printf("%d ", suma[i][j]);
        }
        printf("\n");
    }

    // Liberar la memoria de las matrices
    liberar_matriz(matriz1, n);
    liberar_matriz(matriz2, n);
    liberar_matriz(suma, n);

    return 0;
}

# %% [markdown]
# #### Explicación detallada del Ejercicio 6 - código 2
#
# Este ejercicio permite que el usuario ingrese dos matrices cuadradas de tamaño n × n y calcula la suma de estas dos.
#
# En este ejercicio:
#
# 1. Se importan las librerias necesarias
#
#     `#include <stdio.h>` - Esta libreria permite manejar la entrada y salida de datos (printf,  scanf).
#     `#include <stdlib.h>` - Esta libreria permite el uso de `malloc` (Allocate dynamic memory)
#
# 2. Se crea la primera función **capturar_tamaño**: Esta función va a capturar n, lo que será el tamaño de la matriz. Además en esta se realiza una verificación con un condicional para comprobar que el número ingresado sea valido, es decir entero positivo, en caso de que no se retorna 1 ya que no fue exitoso. Por otro lado, si es valido se retorna el valor de n.
#
# 3. Se crea la segunda función **capturar_matriz**: Esta función captura los datos para crear la matriz. Esta retornará un puntero doble ya que se está manejando en la memoria dinámica y recibe como parámetro n, que es el tamaño de la matriz.
# - En esta función se crea inicialmente una matríz en la memoria dinámica, se utiliza `malloc` para reservar memoria para n punteros.
#
# ```c int** matriz = (int**)malloc(n * sizeof(int*)); ```
#
# `int** matriz`: Es un puntero doble que almacenará las direcciones de cada fila de la matriz.
#
# `(int**)malloc(n * sizeof(int*))`: Asigna memoria para n filas (cada una es un puntero).
#
# ```c
# for (int i = 0; i < n; i++) {
#     matriz[i] = (int*)malloc(n * sizeof(int));
# }
# ```
#
# En este for realizamos la misma asignación de memorias pero en este caso para las columnas:
#
# Se recorre cada fila i y se asigna memoria para n columnas `(n * sizeof(int))`.
# matriz[i] ahora es un puntero que apunta a una fila con n enteros.
#
# 4. Luego de asignar el puntero se utiliza un ciclo for anidado para recorrer la matriz y preguntarle al usuario el elemento que desea ingresar en la posición, este se asigna en la posición y se genera así la matriz. Esto es igual a como se explicó en el primer código.
#
# 5. Se crea un función **liberar_matriz** para liberar la memoria reservada para la matriz: esta recibe como parámetro el puntero que contiene la matriz y el tamaño n de la matriz. Además la función no devuelve nada (void).
# Se recorre la matriz con un ciclo for para acceder a las filas de la matriz.
# Se utiliza ` free(matriz[i]);` para liberar la memoria reservada, tanto de cada fila como de la matriz.
#
# 6. Se define la función principal donde se va a ejecutar el programa.
#
# 7. Se crean las variables neecesarias, en este caso primero creamos la variable `n`, la cual llama a la función capturar_tamaño. Se crean dos matrices de n tamaño como doble puntero. Y po último se crea una nueva matriz, la cual será el resultado de la suma y utilizamos `malloc` para reservar memoria de esta matriz también.
#
# 8. Se calcula la suma de las matrices.
# Para la suma de matrices es necesario implementar un ciclo anidado, para recorrer las matrices y poder acceder a la misma posición en las dos.
# `suma[i][j] = matriz1[i][j] + matriz2[i][j];`
# Con esta linea , asignamos a la posición i, j de la matriz suma(es el resultado) la suma de los elementos que se encuentran en la misma posición de las deos matrices que se van a sumar.
#
# 9. En el siguiente paso se imprime en pantalla la matriz resultante, para esto debemos recorrer la matriz y mostrar el resultado, además saltamos de linea cada que se recorre una fila para mostrarlo con la estructura de una matriz.
#
# 10. Por último es necesario liberar la memoria de los punteros que se tienen, es decir las 3 matrices. Esto lo hacemos llamando a la función liberar_matriz.
#
# 8. Finalmente retornamos 0 para mostrar el fin exitoso de la función principal.

# %% [markdown]
# ***
#
# # Ejercicio 7
