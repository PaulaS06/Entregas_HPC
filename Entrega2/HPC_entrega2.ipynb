# %% [markdown]
# <h3 align="center">High Performance Computing</h3>
# <h3 align="center">Computación de Alto Desempeño</h3>
# <h3 align="center">Entrega 2 - Ejercicios prácticos de C</h3>
# <h3 align="center">Marzo - 2025</h3>
# <h3 align="center">Universidad de Medellín </h3>
# <h5 align="center">Paula S. Meneses Gasca </h5>
#
# ***

# %% [markdown]
# # Introducción

# %% [markdown]
# En este trabajo se hará uso de un nuevo lenguaje de programación para implementar estructuras de datos y algoritmos en C.
# C es utilizada en la computación de alto desempeño por el control que tiene sobre la memoria y su cercanía al hardware, lo que permite escribir código optimizado para tareas computacionalmente exigentes.
#
# Los ejercicios se van a implementar de manera secuencial, buscando entender algunas bases para paralelizar en otro momento. Se van a implementar y evaluar aspectos como la eficiencia del código, el manejo de memoria y el tiempo de ejecución en algunos casos.
#
# De cada ejercicio se explicarán los fundamentos teóricos que fueron aplicados, la estructura del código y los resultados obtenidos. Este análisis servirá el inicio para futuras optimizaciones y mejoras en el desempeño del código.
#
# ***

# %% [markdown]
# **Puntero**: variable que almacena la dirección de memoria de otra variable.
#
# ***

# %% [markdown]
# # Ejercicio 6

# %% [markdown]
# ### Suma de matrices
# **Problema**
#
# Escriba un programa en C que:
#
# 1. Lea desde archivos de datos dos matrices.
# 2. Calcule su suma.
# 3. Muestre la matriz resultante.
#
# **Objetivo**
# - Introducir arreglos bidimensionales.
# - Uso de ciclos anidados.

# %% [markdown]
# Este fue el código que planteé inicialmente, sin embargo al revisarlo me di cuenta que por ejemplo la creación de matrices es la misma para las dos, por lo que decidí cambiarlo y hacerlo con algunas funciones que se llamarían en la principal. El siguiente código fue el planteado en un inicio:

# %%
#include <stdio.h>

// Crear la función principal
int main() {

    // Definir una variable que el usuario ingresa para establecer las dimensiones de las matrices
    int n;

    printf("Ingrese de que tamaño desea la matriz cuadrada: ");
    scanf("%d", &n);

    // Definir las matrices con su tamaño n
    int matriz1[n][n];
    int matriz2[n][n];
    int suma[n][n];
    
    // Pedir al usuario que ingrese los elementos para generar la primera matriz
    printf("Ingrese los elementos de la primera matriz (%d x %d):\n", n, n);
    // Para esto implementamos un ciclo for anidado que recorre la matriz
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            printf("Elemento [%d][%d]: ", i, j);
            scanf("%d", &matriz1[i][j]);
        }
    }
    
    // Pedir al usuario que ingrese los elementos para generar la segunda matriz
    printf("Ingrese los elementos de la segunda matriz (%d x %d):\n", n, n);
   // Para esto implementamos un ciclo for anidado que recorre la matriz
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            printf("Elemento [%d][%d]: ", i, j);
            scanf("%d", &matriz2[i][j]);
        }
    }

    // Calcular la suma de las matrices también con un ciclo for anidado que busca recorrer las matrices y se le asigna a la nueva matriz la suma de las dos matrices
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            suma[i][j] = matriz1[i][j] + matriz2[i][j];
        }
    }

    // Imprimir la matriz resultante en pantalla
    printf("La suma de las matrices es:\n");
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            printf("%d ", suma[i][j]);
        }
        printf("\n");
    }

    return 0; 
}

# %% [markdown]
# #### Explicación detallada del Ejercicio 6 - código 1
#
# Este ejercicio permite que el usuario ingrese dos matrices cuadradas de tamaño n × n y calcula la suma de estas dos.
#
# En este ejercicio:
#
# 1. Se importan las librerias necesarias
#
#     `#include <stdio.h>` - Esta libreria permite manejar la entrada y salida de datos (printf,  scanf).
#
# 2. Se define la función principal donde se va a ejecutar el programa.
#
# 3. Se crean las variables neecesarias, en este caso primero creamos la variable `n`, la cual se le pide al usuario con el `printf`; luego de esto se crean las dos matrices del tamaño n que dió el usuario.
#
# 4. Teniendo n procedemos a pedirle al usuario los datos para cada matriz, estos los recolectamos por medio de un ciclo for en el que recorremos la matriz y le asignamos el número a cada posición. Para esto usamos los índices i y j.
#
# ```c
#     for (int i = 0; i < n; i++) {
#         for (int j = 0; j < n; j++) {
#             printf("Elemento [%d][%d]: ", i, j);
#             scanf("%d", &matriz2[i][j]);
#         }
#     }
# ```
#
# - En este for anidado se recorren las filas con i, mientras i sea menor a el tamaño de la matriz va a realizar el for recorriendo la lista, i se va a incrementar de a 1 para poder iterar.
# - El segundo for se recorren las columnas con j, mientras j sea menor al tamaño de la matriz va a realizar el for recorriendo la lista, al igual que i, j se va a incrementar de a 1 para poder iterar.
# - Con `printf` se le pide al usuario cada número, dentro del ciclo.
# - Con `scanf` se le asigna el valor dado por el usuario a la posición i, j en la que se encuentra.
#
# 5. El ciclo pasado se ejecuta dos veces para capturar las dos matrices.
#
# 6. Para la suma de matrices es necesario implementar un ciclo anidado como el recien explicado, para recorrer las matrices y poder acceder a la misma posición en las dos.
# `suma[i][j] = matriz1[i][j] + matriz2[i][j];`
# Con esta linea , asignamos a la posición i, j de la matriz suma(es el resultado) la suma de los elementos que se encuentran en la misma posición de las deos matrices que se van a sumar.
#
# 7. En el siguiente paso se imprime en pantalla la matriz resultante, para esto debemos recorrer la matriz y mostrar el resultado, además saltamos de linea cada que se recorre una fila para mostrarlo con la estructura de una matriz.
#
# 8. Finalmente retornamos 0 para mostrar el fin exitoso de la función principal.

# %% [markdown]
# Este código se puede organizar de otra manera para que no repita tantas cosas iguales, al crear el nuevo código, donde creo una funcion para capturar n y otra para capturar las matrices, me di cuenta que era necesario realizar un `malloc`, en este punto usé una IA para entender bien el proposito de usarlo y saber en que punto era necesario hacerlo. El código con las nuevas funciones es el siguiente:

# %%
#include <stdio.h>
#include <stdlib.h>

int capturar_tamaño() {
    
    // Definir una variable que el usuario ingresa para establecer las dimensiones de las matrices
    int n;

    printf("Ingrese de que tamaño desea la matriz: ");
    scanf("%d", &n);

    // Validar que el tamaño sea positivo
    if (n <= 0) {
        printf("El tamaño de la matriz debe ser positivo.\n");
        return 1; // Salir con un código de error
    }

    return n; // Retornar el tamaño de la matriz
}

int** capturar_matriz(int n) {

    // Reservar memoria dinámica para la matriz
    int** matriz = (int**)malloc(n * sizeof(int*));
    for (int i = 0; i < n; i++) {
        matriz[i] = (int*)malloc(n * sizeof(int));
    }

    // Pedir al usuario que ingrese los elementos para generar la primera matriz
    printf("Ingrese los elementos de la primera matriz (%d x %d):\n", n, n);
    // Para esto implementamos un ciclo for anidado que recorre la matriz
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            printf("Elemento [%d][%d]: ", i, j);
            scanf("%d", &matriz[i][j]);
        }
    }

    return matriz; 
}

void liberar_matriz(int** matriz, int n) {
    for (int i = 0; i < n; i++) {
        free(matriz[i]);
    }
    free(matriz);
}

int main(int n) {

    // Llamar a la función para capturar el tamaño de la matriz
    n = capturar_tamaño();

    // Definir las matrices con su tamaño n
    int** matriz1 = capturar_matriz(n);
    int** matriz2 = capturar_matriz(n);

    // Asignar memoria dinamica para la matriz suma
    int** suma = (int**)malloc(n * sizeof(int*));
    for (int i = 0; i < n; i++) {
        suma[i] = (int*)malloc(n * sizeof(int));
    }

    // Calcular la suma de las matrices también con un ciclo for anidado que busca recorrer las matrices y se le asigna a la nueva matriz la suma de las dos matrices
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            suma[i][j] = matriz1[i][j] + matriz2[i][j];
        }
    }

    // Imprimir la matriz resultante en pantalla
    printf("La suma de las matrices es:\n");
    for (int i = 0; i < n; i++) {
        for (int j = 0; j < n; j++) {
            printf("%d ", suma[i][j]);
        }
        printf("\n");
    }

    // Liberar la memoria de las matrices
    liberar_matriz(matriz1, n);
    liberar_matriz(matriz2, n);
    liberar_matriz(suma, n);

    return 0;
}

# %% [markdown]
# #### Explicación detallada del Ejercicio 6 - código 2
#
# Este ejercicio permite que el usuario ingrese dos matrices cuadradas de tamaño n × n y calcula la suma de estas dos.
#
# En este ejercicio:
#
# 1. Se importan las librerias necesarias
#
#     `#include <stdio.h>` - Esta libreria permite manejar la entrada y salida de datos (printf,  scanf).
#
#     `#include <stdlib.h>` - Esta libreria permite el uso de `malloc()` (Allocate dynamic memory) y `free()`.
#
# 2. Se crea la primera función **capturar_tamaño**: Esta función va a capturar n, lo que será el tamaño de la matriz. Además en esta se realiza una verificación con un condicional para comprobar que el número ingresado sea valido, es decir entero positivo, en caso de que no se retorna 1 ya que no fue exitoso. Por otro lado, si es valido se retorna el valor de n.
#
# 3. Se crea la segunda función **capturar_matriz**: Esta función captura los datos para crear la matriz. Esta retornará un puntero doble ya que se está manejando en la memoria dinámica y recibe como parámetro n, que es el tamaño de la matriz.
# - En esta función se crea inicialmente una matríz en la memoria dinámica, se utiliza `malloc` para reservar memoria para n punteros.
#
# ```c
# int** matriz = (int**)malloc(n * sizeof(int*));
# ```
#
# `int** matriz`: Es un puntero doble que almacenará las direcciones de cada fila de la matriz.
#
# `(int**)malloc(n * sizeof(int*))`: Asigna memoria para n filas (cada una es un puntero).
#
# ```c
# for (int i = 0; i < n; i++) {
#     matriz[i] = (int*)malloc(n * sizeof(int));
# }
# ```
#
# En este for realizamos la misma asignación de memorias pero en este caso para las columnas:
#
# Se recorre cada fila i y se asigna memoria para n columnas `(n * sizeof(int))`.
# matriz[i] ahora es un puntero que apunta a una fila con n enteros.
#
# 4. Luego de asignar el puntero se utiliza un ciclo for anidado para recorrer la matriz y preguntarle al usuario el elemento que desea ingresar en la posición, este se asigna en la posición y se genera así la matriz. Esto es igual a como se explicó en el primer código.
#
# 5. Se crea un función **liberar_matriz** para liberar la memoria reservada para la matriz: esta recibe como parámetro el puntero que contiene la matriz y el tamaño n de la matriz. Además la función no devuelve nada (void).
# Se recorre la matriz con un ciclo for para acceder a las filas de la matriz.
# Se utiliza ` free(matriz[i]);` para liberar la memoria reservada, tanto de cada fila como de la matriz.
#
# 6. Se define la función principal donde se va a ejecutar el programa.
#
# 7. Se crean las variables neecesarias, en este caso primero creamos la variable `n`, la cual llama a la función capturar_tamaño. Se crean dos matrices de n tamaño como doble puntero. Y po último se crea una nueva matriz, la cual será el resultado de la suma y utilizamos `malloc` para reservar memoria de esta matriz también.
#
# 8. Se calcula la suma de las matrices.
# Para la suma de matrices es necesario implementar un ciclo anidado, para recorrer las matrices y poder acceder a la misma posición en las dos.
# `suma[i][j] = matriz1[i][j] + matriz2[i][j];`
# Con esta linea , asignamos a la posición i, j de la matriz suma(es el resultado) la suma de los elementos que se encuentran en la misma posición de las deos matrices que se van a sumar.
#
# 9. En el siguiente paso se imprime en pantalla la matriz resultante, para esto debemos recorrer la matriz y mostrar el resultado, además saltamos de linea cada que se recorre una fila para mostrarlo con la estructura de una matriz.
#
# 10. Por último es necesario liberar la memoria de los punteros que se tienen, es decir las 3 matrices. Esto lo hacemos llamando a la función liberar_matriz.
#
# 8. Finalmente retornamos 0 para mostrar el fin exitoso de la función principal.

# %% [markdown]
# En la carpeta del repositorio Entregas_HPC/Entrega2/Ejercicio6, se encuentran los dos códigos explicados anteriormente.
# - suma_matrices_.c contiene el primer código
# - suma_matrices.c contiene el segundo código

# %% [markdown]
# ***
#
# # Ejercicio 7

# %% [markdown]
# ### Listas enlazadas
#
# **Problema**
#
# Implemente una lista enlazada en C con las siguientes funciones:
#
# 1. Insertar un elemento al final.
# 2. Mostrar la lista.
# 3. Eliminar un nodo dado su valor.
#
# **Objetivo**
# - Introducir struct, malloc y free.
# - Manejo de punteros y memoria dinámica.

# %%
#include <stdio.h>
#include <stdlib.h>

// Utilizar Structs para definir la estructura de los nodos de la lista enlazada
struct Node {
    int data;
    struct Node* next; // El siguiente nodo corresponde a la dirección de memoria del siguiente nodo (es de tipo struct Node y con la referencia *)
}; 

// NOTAAAA: Para acceder a la estructura es necesario crear una variable de tipo struct Node.

void insertar_nodo_final(struct Node** head, int value){
    struct Node* newNode = (struct Node*)malloc(sizeof(struct Node)); // Crear un nuevo nodo
    newNode->data = value;  // Asignar el valor al nuevo nodo
    newNode->next = NULL; 

    if (*head == NULL){
        *head = newNode; // Si la lista está vacía, el nuevo nodo es el primero
    }
    else {
        struct Node* current = *head; // Crear un puntero auxiliar para recorrer la lista
        while (current->next != NULL){
            current = current->next; // Avanzar al siguiente nodo
        }
        current->next = newNode; // Asignar el nuevo nodo al final de la lista
        }
    }

void imprimir_lista(struct Node* head){
    if (head == NULL){
        printf("La lista está vacía.\n");
        return;
    }

    struct Node* current = head; // Crear un puntero auxiliar para recorrer la lista
    while (current != NULL){
        printf("%d -> ", current->data); // Imprimir el valor del nodo actual
        current = current->next; // Avanzar al siguiente nodo
    }

    printf("NULL\n"); // Indicar el final de la lista
    }

int eliminar_nodo(struct Node** head, int value){
    if (*head == NULL){
        return 0; // La lista está vacía
    }

    struct Node* current = *head; // Crear un puntero auxiliar para recorrer la lista
    struct Node* previous = NULL; // Crear un puntero para el nodo anterior

    while (current != NULL && current->data != value){
        previous = current; // Guardar el nodo anterior
        current = current->next; // Avanzar al siguiente nodo
    }

    if (current == NULL){
        return 1; // El valor no se encontró en la lista
    }

    if (previous == NULL){
        *head = current->next; // El nodo a eliminar es el primero
    }
    else {
        previous->next = current->next; // Eliminar el nodo de la lista
    }

    free(current); // Liberar la memoria del nodo eliminado
    return 0; // El nodo fue eliminado con éxito
    }

int main(){
    struct Node* head = NULL; // Inicializar la lista vacía

    insertar_nodo_final(&head, 10);
    insertar_nodo_final(&head, 20);
    insertar_nodo_final(&head, 30);

    printf("Lista enlazada: ");
    imprimir_lista(head); // Imprimir la lista enlazada

    printf("Eliminando 20...\n");
    eliminar_nodo(&head, 20);
    imprimir_lista(head); // Imprimir la lista enlazada

    return 0;
    
    }

# %% [markdown]
# ### Explicación detallada del ejercicio 7
#
# Este ejercicio tiene la implementación de una lista enlazada.
#
# En este esejercicio:
# 1. Se importan las librerias necesarias
#
#     `#include <stdio.h>` - Esta libreria permite manejar la entrada y salida de datos (printf,  scanf).
#
#     `#include <stdlib.h>` - Esta libreria permite el uso de `malloc()` (Allocate dynamic memory) y `free()`.
#
# 2. Se define la estructura del Node, la cual va a representar cada Nodo de la lista enlazada. Este cuenta con valor que es un número entero y con un next que será un puntero al siguiente Nodo de la lista.
#
# 3. Función para Insertar un Nodo al Final, esta función recibe un parametro que será el valor del nodo que se va a insertar y recibe el primer nodo de la estructura para tener acceso a toda.
# - Inicialmente se va a crear el nuevo nodo que se va a ingresar, para esto: se reserva memoria para un nuevo nodo con `malloc()`, luego de esto se le asigna el valor recibido, al "data" que es donde se ubica el valor del Nodo, y finalmente al Next del nodo creado se inicializa un puntero en Null ya que este será el último Nodo.
# - Luego de esto se va a agregar este nodo a la estructura, para esto tenemos un condicional --
#         Primera condición: si el head (la cabeza de la estructura) es Null, significa que la estructura está vacía, por lo que el nuevo nodo se le asigna al head.
#         Si no se cumple la primera: primero se crea un puntero auxiliar para recorrer la estructura sin modificar nada, se recorre buscando el último Nodo(es decir el Nodo donde su next es None) esto se realiza por medio de un while, cuando se encuentra se enlaza el nuevo nodo al final, es decir que pasa a ser el next del actual último Nodo.
#
# 4. Función para imprimir la lista, esta función no retorna nada y se encarga de mostrar en pantalla la estructura. Para esto la función recibe la cabeza de la estructura para tener acceso a toda.
# - Se inicia con un condicional donde: si no hay nada en la cabeza, es decir que es NULL, se imprime un mensaje diciendo que la lista está vacía.
# - Si la cabeza no es NULL, se crea un puntero auxiliar para recorrer la estructura y tener acceso a cada elemento de esta: mientras no sea NULL el nodo en el que se encuentra, se imprime el valor del nodo actual y una "flecha (->)" para que sea más visual la impresión.
# - Cuando se llegue al final se imprime NULL para saber que ya se terminó.
#
# 5. Función para eliminar un Nodo teniendo un valor, esta recibe la cabeza para tener acceso a toda la estructura y el valor que se va a eliminar:
# - Se inicia con un condicional donde: si no hay nada en la cabeza, es decir que es NULL, se retorna inmeidatamente.
# - Luego se crean dos punteros auxiliares, uno para guardar el nodo anterior y el otro para recorrer la estructura.
# - Se crea un ciclo que se va a cumplir cuando no se haya llegado al final y el valor del nodo actual sea diferente al vaor que se quiera eliminar.
#             luego de comprobado esto le asigna al nodo anterior el actual, para poder reemplazar el actual por su next y así recorrer la estructura.
#             Se inicia un condicional que se cumple si el nodo que está recorriendo llega al final de la estructura, si llega es porque no se encontró el valor buscado, en este caso se retorna 1 (no fue exitoso)
#             Si el nodo anterio sigue siendo NULL, es porque el nodo que se va a eliminar está en la primera. En este caso se elimina el primer nodo y para esto se le asigna al head el next del nodo a eliminar, es decir el segundo nodo de la estructura.
#             si no pues se sigue recorriendo.
# - Por último se libera la memoria del nodo creado para recorrer y se retorna 0(exitosamente).
#
#  6. Función Main: Se inicializa la etructura con el head vacía, luego se agregan nodos llamando al método "Insertar un Nodo al Final" , luego se imprime la lista para observar que fueron agregados exitosamente, llamando al método que la imprime, y para probar el método de eliminar se elimina uno de los nodos ya agregados y se vuelve a imprimir la lista para verificar la eliminación.
#
#  Se retorna 0 para una salida exitosa y con esto finaliza el programa.

# %% [markdown]
# ***
# # Ejercicio 8

# %% [markdown]
# ###  Ordenamiento con Burbuja (Uso de Punteros)
#
# **Problema**
#
# Escriba un programa que:
#
# 1. Solicite un arreglo de enteros.
# 2. Ordene el arreglo usando punteros en lugar de índices.
#
# **Objetivo**
# - Introducir aritmética de punteros.

# %% [markdown]
# #### Código con punteros (Principal)

# %%
//Código de ordenamiento de burbuja usando punteros en C

#include <stdio.h>

// Función para intercambiar dos valores
void intercambiar(int *a, int *b) {
    int temp = *a; // Guardamos el valor de a en temp
    *a = *b; // Asignamos el valor de b a a 
    *b = temp; // Asignamos el valor de temp a b
}

// Función de ordenamiento de burbuja usando punteros
void ordenarBurbuja(int *arr, int n) {
    int flag; // Variable para controlar si hubo intercambio
    do {
        flag = 0; // control de que ya está ordenado el array
        for (int i = 0; i < n - 1; i++) { // Recorremos el arreglo usando punteros
            if (*(arr + i) > *(arr + i + 1)) {
                intercambiar(arr + i, arr + i + 1);
                flag = 1; // Hubo un intercambio
            }
        }
    } while (flag == 1); // Repetir mientras haya intercambios
}

// Función para imprimir el arreglo
void imprimirArreglo(int *arr, int n) {
    for (int i = 0; i < n; i++) { // Recorrer el arreglo usando punteros
        printf("%d ", *(arr + i)); // Imprimir cada elemento
    }
    printf("\n"); // Salto de línea al final
}

int main() {
    int n;
    printf("Ingrese el tamaño del arreglo: "); // Solicitar al usuario el tamaño del arreglo
    scanf("%d", &n); // Leer el tamaño del arreglo
    
    if (n <= 0) { // Validar que el tamaño sea positivo
        printf("El tamaño del arreglo debe ser mayor que cero.\n");
        return 1; // Salir del programa si el tamaño no es válido
    } 

    int arr[n];
    printf("Ingrese %d elementos: ", n); // Solicitar al usuario los elementos del arreglo
    for (int i = 0; i < n; i++) {
        scanf("%d", arr + i); // Leer cada elemento del arreglo usando punteros
    }
    
    printf("Arreglo original: ");
    imprimirArreglo(arr, n); // Imprimir el arreglo original
    
    ordenarBurbuja(arr, n); // Llamar a la función de ordenamiento
    
    printf("Arreglo ordenado: ");
    imprimirArreglo(arr, n); // Imprimir el arreglo ordenado
    
    return 0; // Salir del programa def forma exitosa
}

# %% [markdown]
# ### Explicación detallada del ejercicio 8 con punteros
#
# Este ejercicio tiene la implementación de un ordenamiento de burbuja, el cual es un algoritmo que compara y cambia de posición elementos en una lista por medio de los punteros de cada elemento.
#
# El cógido para la realización del ejercicio con punteros es:
#
# 1. Se importan las librerias necesarias
#
#     `#include <stdio.h>` - Esta libreria permite manejar la entrada y salida de datos (printf,  scanf).
#
# 2. Función para intercambiar dos valores: esta primeramente no retorna nada y recibe dos punteros que son enteros (int *a, int *b). Se hará uso de una variable temporal para asignarle el primer puntero que va a cambiar de valor, luego de esto se le asigna a esta variable almacenada en el temporal, la segunda variable y finalmente a esta última variable se le asigna el almacenado en la variable temporal.
#
# 3. Función para realizar el ordenamiento de burbuja: esta primeramente no retorna nada y recibe dos parametros, un puntero que apunta al array y un entero n que indica la cantidad de elementos en el array (int *arr, int n). Además de esto se va a inicializar una variable que sería un entero y se utilizará como "contador", esta es para mantener un control de los ciclos que se van a utilizar.
#
#     Se realizará un Do, While mientras haya intercambios en hacer, es decir:
#
#     Do: el flag se va a inicializar en cero y cambiará su estado cada que entre al for y haga un intercambio para poder ejecutar el while.
#
#     El for que está en el do va a ejecutarse para recorrer el arreglo. Se crea la variable i inicializando en cero para empezar a comparar en la primera posición y se ejecutará mientras i sea menor que el tamaño del arreglo, ya que inicia con la posición en cero y es necesario que llegue hasta la penultima posición para comparar con la última.
#
#     Cuando ingresa al for se verifica por medio de un if si el elemento en la posición en la que estamos es mayor que el elemento de la siguiente posición; esto lo hacemos por medio de punteros. Como ya tenemos la referencia de memoria del array y con esto tenemos acceso al array.
#
#     Como arr ya es un puntero al primer elemento del arreglo, podemos acceder a la posición sumándole un entero i, luego de esto usamos el operador * para obtener el valor contenido en esa dirección de memoria.
#
#     Por ejemplo: *(arr + i) accede al elemento en la posición i, y *(arr + i + 1) accede al siguiente elemento.
#     Entonces `(*(arr + i) > *(arr + i + 1))` evalúa si el elemento actual es mayor que el siguiente, para saber si se debe hacer un intercambio. "En este punto se utilizó ayuda de una IA para explicar tecnicamente como funcionan los punteros"
#
#     Si esto se cumple significa que están en desorden, por lo que se llama a la función que se encarga de intercambiar las variables pasando como parametros los punteros de `(arr + i)` y `(arr + i + 1)`, además se activa la bandera para indicar que hubo un intercambio y sebe seguir en el Do-While.
#
# 4. Función para imprimir el arreglo: esta primeramente no retorna nada y recibe dos parametros, un puntero al array y un entero n que indica la cantidad de elementos en el array (int *arr, int n). Se realiza un for similar al anterior para recorrer el array e imprimirlo. En este hacemos uso de la variable i para incrementarlo y pasar por cada posición mientras este sea menor que el tamaño. Simplemente imprimimos el valor que se encuentra en la posición accediendo al puntero del `(arr + i)` e imprimimos un salto de linea al terminar el for.
#
# 5. Función Main: Primero se crea la variable n para preguntarle al usuario de que tamaño desea el arreglo y alamacenar este valor en la variable. Luego se crea el array de tamaño n, se le pregunta al usuario que elementos quiere en el array y por medio de un ciclo for se añaden los n elementos al array sumandole la posición i. El ciclo es exactamente igual al realizado para imprimir el arreglo.
#
#     Para mostrar los resultados se llama a imprimir arreglo pasando el array ingresado por el usuario, luego se ordena el arreglo llamando a la función ordenarBurbuja, y por último se imprime el arreglo ya ordenado para que sea visualizado.
#
#     Se retorna 0 para una salida exitosa y con esto finaliza el programa.

# %% [markdown]
# #### Código con índices

# %%
//Código de ordenamiento de burbuja usando índices en C

#include <stdio.h>

// Función para intercambiar dos valores
void intercambiar(int *a, int *b) {
    int temp = *a; // Guardamos el valor de a en temp
    *a = *b; // Asignamos el valor de b a a 
    *b = temp; // Asignamos el valor de temp a b
}

// Función de ordenamiento de burbuja usando índices
void ordenarBurbuja(int arr[], int n) {
    int flag;
    do {
        flag = 0; // control de que ya está ordenado el array
        for (int i = 0; i < n - 1; i++) { // Recorremos el arreglo
            if (arr[i] > arr[i + 1]) {
                intercambiar(&arr[i], &arr[i + 1]);
                flag = 1; // Hubo un intercambio
            }
        }
    } while (flag == 1); // Repetir mientras haya intercambios
}

// Función para imprimir el arreglo
void imprimirArreglo(int arr[], int n) {
    for (int i = 0; i < n; i++) { // Recorrer el arreglo
        printf("%d ", arr[i]); // Imprimir cada elemento
    }
    printf("\n"); // Salto de línea al final
}

int main() {
    int n;
    printf("Ingrese el tamaño del arreglo: "); // Solicitar al usuario el tamaño del arreglo
    scanf("%d", &n); // Leer el tamaño del arreglo
    
    if (n <= 0) { // Validar que el tamaño sea positivo
        printf("El tamaño del arreglo debe ser mayor que cero.\n");
        return 1; // Salir del programa si el tamaño no es válido
    } 
    
    int arr[n];
    printf("Ingrese %d elementos: ", n); // Solicitar al usuario los elementos del arreglo
    for (int i = 0; i < n; i++) {
        scanf("%d", &arr[i]); // Leer cada elemento del arreglo
    }
    
    printf("Arreglo original: ");
    imprimirArreglo(arr, n); // Imprimir el arreglo original
    
    ordenarBurbuja(arr, n); // Llamar a la función de ordenamiento
    
    printf("Arreglo ordenado: ");
    imprimirArreglo(arr, n); // Imprimir el arreglo ordenado
    
    return 0;
}

# %% [markdown]
# ### Explicación detallada del ejercicio 8 con índices
#
# Este ejercicio tiene la implementación de un ordenamiento de burbuja, el cual es un algoritmo que compara y cambia de posición elementos en una lista por medio de los índices del arreglo.
#
# El cógido para la realización del ejercicio con índices es:
#
# 1. Se importan las librerias necesarias
#
#     `#include <stdio.h>` - Esta libreria permite manejar la entrada y salida de datos (printf,  scanf).
#
# 2. Función para intercambiar dos valores: esta primeramente no retorna nada y recibe dos punteros que son enteros (int *a, int *b). Se hará uso de una variable temporal para asignarle el primer puntero que va a cambiar de valor, luego de esto se le asigna a esta variable almacenada en el temporal, la segunda variable y finalmente a esta última variable se le asigna el almacenado en la variable temporal.
#
# 3. Función para realizar el ordenamiento de burbuja: esta primeramente no retorna nada y recibe dos parametros, un array que sería la lista y un entero n que indica la cantidad de elementos en el array (int arr[], int n). Además de esto se va a inicializar una variable que sería un entero y se utilizará como "contador", esta es para mantener un control de los ciclos que se van a utilizar.
#
#     Se realizará un Do, While mientras haya intercambios en hacer, es decir:
#
#     Do: el flag se va a inicializar en cero y cambiará su estado cada que entre al for y haga un intercambio para poder ejecutar el while.
#
#     El for que está en el do va a ejecutarse para recorrer el arreglo. Se crea la variable i inicializando en cero para empezar a comparar en la primera posición y se ejecutará mientras i sea menor que el tamaño del arreglo, ya que inicia con la posición en cero y es necesario que llegue hasta la penultima posición para comparar con la última.
#
#     Cuando ingresa al for se verifica por medio de un if si el elemento en la posición en la que estamos es mayor que el elemento de la siguiente posición; si esto se cumple significa que están en desorden, por lo que se llama a la función que se encarga de intercambiar las variables pasando las direcciones de arr[i] y arr[i+1], además se activa la bandera para indicar que hubo un intercambio y sebe seguir en el Do-While.
#
# 4. Función para imprimir el arreglo: esta primeramente no retorna nada y recibe dos parametros, un array que sería la lista y un entero n que indica la cantidad de elementos en el array (int arr[], int n). Se realiza un for similar al anterior para recorrer el array e imprimirlo. En este hacemos uso de la variable i para incrementarlo y pasar por cada posición mientras este sea menor que el tamaño. Simplemente imprimimos el elemento que se encuentra en la posición e imprimimos un salto de linea al terminar el for.
#
# 5. Función Main: Primero se crea la variable n para preguntarle al usuario de que tamaño desea el arreglo y alamacenar este valor en la variable. Luego se crea el array de tamaño n, se le pregunta al usuario que elementos quiere en el array y por medio de un ciclo for se añaden los n elementos al array. El ciclo es exactamente igual al realizado para imprimir el arreglo.
#
#     Para mostrar los resultados se llama a imprimir arreglo pasando el array ingresado por el usuario, luego se ordena el arreglo llamando a la función ordenarBurbuja, y por último se imprime el arreglo ya ordenado para que sea visualizado.
#
#     Se retorna 0 para una salida exitosa y con esto finaliza el programa.

# %% [markdown]
# ***
# # Ejercicio 9

# %% [markdown]
# ###  Calculadora
#
# **Problema**
#
# Implemente una calculadora con punteros a funciones que realice operaciones básicas (+, -, *, /).
#
# **Objetivo**
# - Introducir punteros a funciones.

# %%
#include <stdio.h>

// Declaración de funciones
float sumar(float a, float b) {
    return a + b; // Definición de la función sumar
}

float restar(float a, float b) {
    return a - b; // Definición de la función restar
}

float multiplicar(float a, float b) {
    return a * b; // Definición de la función multiplicar
}

float dividir(float a, float b) {
    if (b == 0) { // Manejo de error para división por cero
        printf("Error: División por cero\n");
        return 1;
    }
    return a / b; // Definición de la función dividir
}

// Función calcular que recibe operador y operandos
void calcular(char operador, float x, float y) {
    // Declarar puntero a función que reciba dos floats y devuelva float
    float (*operacion)(float, float) = NULL;

    // Asignar la función al puntero según el operador
    if (operador == '+') {
        operacion = sumar;
    } else if (operador == '-') {
        operacion = restar;
    } else if (operador == '*') {
        operacion = multiplicar;
    } else if (operador == '/') {
        operacion = dividir;
    } else {
        printf("Operador no válido.\n");
        return; // definir los condicionales para identificar la operación que se va a realizar
    }

    // Ejecutar la función a través del puntero
    float resultado = operacion(x, y); // Llamar a la función correspondiente
    printf("Resultado: %.2f\n", resultado); // Imprimir el resultado
}

int main() {
    float x, y;
    char operador;

    // Leer entrada del usuario
    printf("Ingrese el primer número: ");
    scanf("%f", &x); // Leer el primer número

    printf("Ingrese el segundo número: ");
    scanf("%f", &y); // Leer el segundo número
    
    printf("Ingrese el operador (+, -, *, /): ");
    scanf(" %c", &operador); // Leer el operador

    calcular(operador, x, y); // Llamar a la función calcular con los valores ingresados

    return 0; // Retornar 0 para indicar que el programa terminó correctamente
}

# %% [markdown]
# ### Explicación detallada del ejercicio 9
#
# Este ejercicio tiene la implementación de una calculadora que permite realizar operaciones matemáticas básicas como suma, resta, multiplicación y división.
#
# El cógido para la realización del ejercicio es:
#
# 1. Se importan las librerias necesarias
#
#     `#include <stdio.h>` - Esta libreria permite manejar la entrada y salida de datos (printf,  scanf).
#
# 2. Se crean las funciones para cada operación, estas funciones simplemente reciben dos float y retorna el resultado de operarlos. En el caso de la función para dividir es necesario comprobar que el denominador, o sea b, no sea cero para que no salga ningún error.
#
# 3. Función calcular: En esta se reciben los números y un string que represente la operación que se va a hacer. Se declara un puntero a función llamado operación, es decir que va a apuntar a cualquier función que reciba dos float y devuelva float.
#
#     Luego de esto realizamos un condicional donde se revisa el operador y dependiendo de cual sea se llama a la función, ya sea suma, resta, multiplicación o dividión. Y en caso de que no sea un operador válido, se muestra un mensaje.
#
#     Para ejecutar la función que apunta a operación, esta se llama en una variable resultado y se le mandan las variables con los números a operar.
#     Finalmente se imprime el resultado con solo 2 decimales.
#
# 4. Función main: Se crean las dos variables de los números y el string (char) que recibirá con la operación.
#
#     Se le pide al usuario los números y se leen en la variables x, y, luego se le pide el operador y se lee. Finalmente se llama a la función calcular pasandole los parámetros.
#
# Se retorna 0 para una salida exitosa y con esto finaliza el programa.

# %% [markdown]
# ***
# # Ejercicio 10

# %% [markdown]
# ###  Implementación de una Pila usando listas enlazadas con punteros
#
# **Problema**
#
# Implemente una pila con memoria dinámica que permita:
#
# 1. push(): Insertar elementos.
# 2. pop(): Extraer elementos.
# 3. mostrar(): Imprimir la pila.
#
# **Objetivo**
# - Introducir gestión de memoria dinámica con malloc y free.

# %%
#include <stdio.h>
#include <stdlib.h>

// Utilizar Structs para definir la estructura de los Nodes de la lista enlazada
struct Node {
    int data;
    struct Node* next; // El siguiente Node corresponde a la dirección de memoria del siguiente Node (es de tipo struct Node y con la referencia *)
}; 

// Función para insertar un elemento (push)
void push(struct Node** pila, int valor) { 
    struct Node* newNode = (struct Node*)malloc(sizeof(struct Node)); // Asignar memoria para el nuevo nodo auxiliar 
    if (newNode == NULL) { // verificar si se pudo asignar memoria
        printf("Error: No se pudo asignar memoria.\n");
        return;
    }
    newNode->data = valor; // Asignar el valor al nuevo nodo
    newNode->next = *pila;  // enlazar el nuevo nodo al tope de la pila
    *pila = newNode; // Actualizar el tope de la pila
    printf("Elemento %d agregado a la pila.\n", valor); // Mensaje de éxito
}

// Función para eliminar un elemento (pop)
int pop(struct Node** pila) {
    if (*pila == NULL) {
        printf("Error: Pila vacía\n");
        return 1;  // Retorna 1 si la pila está vacía, no fue exitoso
    }
    struct Node* temp = *pila; // Guardar el nodo a eliminar en un nodo temporal
    int valor = temp->data; // Guardar el valor del nodo a eliminar para poder retornarlo
    *pila = temp->next;  // Actualizar el tope de la pila al siguiente nodo del eliminado
    free(temp); // Liberar memoria del nodo eliminado
    return valor; // Retornar el valor del nodo eliminado
}

// Función para mostrar la pila
void mostrar(struct Node* pila) {
    if (pila == NULL) {
        printf("Pila vacía\n");
        return; // Si la pila está vacía, no hay nada que mostrar
    }

    printf("Estado de la pila:\n"); 
    struct Node* actual = pila; // Crear un nodo auxiliar para recorrer la pila
    while (actual != NULL) { // Mientras no se llegue al final de la pila
        printf("%d\n", actual->data); // Imprimir el valor del nodo actual
        actual = actual->next; // Mover al siguiente nodo con el next(puntero al siguiente nodo)
    }
}

// Liberar toda la memoria de la pila
void liberarPila(struct Node** pila) {
    while (*pila != NULL) { // Mientras la pila no esté vacía
        struct Node* temp = *pila; // Guardar el nodo a liberar en un nodo temporal
        *pila = temp->next; // Actualizar el tope de la pila al siguiente nodo
        free(temp); // Liberar memoria del nodo eliminado
    }
}

// Función principal
int main() {
    struct Node* pila = NULL; // Inicializar la pila como NULL (vacía)

    // Pruebas
    push(&pila, 5);
    push(&pila, 10);
    push(&pila, 15); // Agregar 3 elementos a la pila
    mostrar(pila); // Mostrar la pila después de los push realizados

    printf("\nPop: %d\n", pop(&pila));  // Eliminar un elemento de la pila y mostrar el valor eliminado
    mostrar(pila);

    printf("\nPop: %d\n", pop(&pila));
    mostrar(pila);

    printf("\nPop: %d\n", pop(&pila));
    mostrar(pila);

    liberarPila(&pila);  // Limpieza final de la pila para liberar la memoria ocupada
    return 0; // Retornar 0 para indicar que el programa se ejecutó exitosamente
}

# %% [markdown]
# ### Explicación detallada del ejercicio 10
#
# Este ejercicio tiene la implementación de una pila usando listas enlazadas con punteros, que sigue la estructura LIFO(último en entrar, primero en salir).
#
# El cógido para la realización del ejercicio es:
#
# 1. Se importan las librerias necesarias
#
#     `#include <stdio.h>` - Esta libreria permite manejar la entrada y salida de datos (printf,  scanf).
#
#     `#include <stdlib.h>` - Esta libreria permite el uso de `malloc()` (Allocate dynamic memory) y `free()`.
#
# 2. Se define la estructura del Node, la cual va a representar cada Nodo de la lista enlazada. Este cuenta con valor que es un número entero y con un next que será un puntero al siguiente Nodo de la lista.
#
# 3. Función push: esta función recibe un parametro que será el valor del nodo que se va a insertar y recibe el primer nodo de la estructura para tener acceso a toda.
#
# - Inicialmente se va a crear el nuevo nodo que se va a ingresar, para esto: se reserva memoria para un nuevo nodo con `malloc()`, luego de esto se le asigna el valor recibido, al "data" que es donde se ubica el valor del Nodo. El nuevo nodo apunta al antiguo tope de la pila, y luego, se actualiza el tope de la pila con el nuevo nodo.
#
# 4. Función para eliminar el último elemeneto en entrar: esta función recibe la dirección de la pila para modificarla. Primero se realiza un condicional donde se verifica si la pila está vacía, para esto se evalua la dirección de la pila si es NULL, en este caso retorna 1 ya que no fue exitoso.
#
#     Si no está vacía, se guarda el nodo del tope en un nodo temporal para evitar eliminarlo antes de tiempo, luego se extrae el valor y se mueve el tope al siguiente nodo por medio del nodo temporal. Finalmente se libera la memoria del nodo que se eliminó y se retorna el valor que fue retirado.
#
# 5. Función para mostrar la pila, esta función no retorna nada y se encarga de mostrar en pantalla la estructura. Para esto la función recibe el tope de la pila. Primero se realiza un condicional donde se verifica si la pila está vacía, para esto se evalua la dirección de la pila si es NULL, en este caso no se retorna nada ya que no fue exitoso.
#
#     Si no está vacía, se crea un puntero auxiliar para recorrer la estructura y tener acceso a cada elemento de esta: mientras no sea NULL el nodo en el que se encuentra, se imprime la data o valor del nodo actual y una "flecha (->)" para que sea más visual la impresión. Luego de imprimir se reemplaza el auxiliar por el next y así hasta recorrerla.
#
# 6. Función para liberar la Pila al terminar: esta función recorre la pila y libera toda la memoria usada, evitando fugas de memoria. Se recorre por medio de un While que accede a la referencia de la pila, y mientras esta exista se recorre con un nodo temporal que se libera con `free()`, en cada iteración.
#
# 7. Función main: se crea una estructura para empezar la pila con un nodo inicial, ese empieza en NULL, es decir vacío. Para probar llamamos a la función `push()` que se encarga de añadir los elementos. Al añadirlos imprimimos llamando a `mostrar()` para comprobar que se han añadido exitosamente. Luego de esto hacemos `pop()` y mostramos la pila por cada elemento que se elimina. Finalmente llamamos a `liberarPila()` para evitar fugas en el sistema.
#
# Se retorna 0 para una salida exitosa y con esto finaliza el programa.

# %% [markdown]
# # Conclusión
#
# En esta entrega se realizaron unos ejercicios en c de manera secuencial, estos permitieron aumentar el conocimiento de las estructuras de datos básicas, el manejo de punteros y referencias de memoria, y el manejo de memoria dinámica.
# Se implementaron funciones como malloc, las que permitieron crear estructuras ajustables al tamaño de los datos ingresados por el usuario, esto ayuda a la optimización de la memoria. También el uso de punteros para almacenar la dirección de memoria de un objeto y así evitar fugas y errores.
#
# Estos ejercicios permitieron que el conociento sobre c las estructuras computacionales más importantes fueran mayor, abriendo paso a identificar que tipo de problemas se pueden paralelizar y que estructuras se pueden utilizar para mejores resultados.
#
# Además de esto es importante resaltar que el uso de herramientas como la inteligencia artificial sirvió como un apoyo complementario en trabajo, estaprincipalmente ayudó para mejorar la comprensión de algunos conceptos complejos, también fue de ayuda para resolver dudas puntuales sobre algunos ejercios, y como una ayuda para documentar el código de una buena forma. En conclusión la IA se utilizó de una manera responsable para el entendimiento de los conceptos y mejorar la calidad del trabajo final.
